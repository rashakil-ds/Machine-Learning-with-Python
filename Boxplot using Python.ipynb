# %% [markdown]
# # Boxplot with matplotlib

# %%
import matplotlib.pyplot as plt
# Sample dataset
data = [1,2,3,3,5,7,7,8,9,10,20]
# Create a figure and axis
fig, ax = plt.subplots()

# Create a box plot
ax.boxplot(data)

# Add labels and title
ax.set_xlabel('Data')
ax.set_ylabel('Values')
ax.set_title('Box Plot Example')
# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
# Sample dataset
data = [1,2,3,3,5,7,7,8,9,10,-15]
# Create a figure and axis
fig, ax = plt.subplots()

# Create a box plot
ax.boxplot(data)

# Add labels and title
ax.set_xlabel('Data')
ax.set_ylabel('Values')
ax.set_title('Box Plot Example')
# Display the plot
plt.show()

# %% [markdown]
# # Boxplot with Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample dataset
data = [1,2,3,3,5,7,7,8,9,10,-15]

# Create a box plot
sns.boxplot(data=data)

# Add labels and title
plt.xlabel('Data')
plt.ylabel('Values')
plt.title('Box Plot Example')

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample dataset
data = [1,2,3,3,5,7,7,8,9,10,15]

# Create a box plot
sns.boxplot(data=data)

# Add labels and title
plt.xlabel('Data')
plt.ylabel('Values')
plt.title('Box Plot Example')

# Display the plot
plt.show()

# %% [markdown]
# Visit our data science courses: https://www.aiquest.org/
#
# Cell: +8801704265972
